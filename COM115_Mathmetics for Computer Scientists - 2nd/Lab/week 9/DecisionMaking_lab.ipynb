# %% [markdown]
# # Decision Making - Lab Exercises

# %% [markdown]
# 1\. Complete the exercises (7.1 - 7.4) in the main Decision Making notebook if you have not done so already.

# %% [markdown]
# 2\. Use the graphical approach from section 7.3 to solve the truck rental problem from Exercise 7.1, i.e. plot the constraints, identify the feasible region and then identify the corner of this region that represents the solution. (Don't worry too much about getting the shading of the feasible region as long as you know where the feasible region is.)

# %% [markdown]
# 3\. Check your solution in question 2 by solving appropriate simultaneous equations as we did at the end of section 7.3 in the notes.

# %% [markdown]
# 4\. Solve the truck rental problem using the Python approach from section 7.4 of the notes.

# %% [markdown]
# 5\. Consider again the truck rental problem from Exercise 7.1, but now suppose that the company has discovered their figures are mistaken. They need to ship slightly more refigerated goods (at least 4720 cubic feet) and correspondingly less non-refigerated goods (at least 5780 cubic feet). Modify the constraints and re-run your solution from question 4.
#
# Can you identify a problem with the solution?
#
# How would you resolve this problem? (Hint: consider changing how you create the decision variables by looking up the documentation on the [LpVariable](https://) function.)

# %% [markdown]
# 6\. A toy manufacturer plans limited editions of three toys using some surplus materials. The first toy is to be priced at £15, the second at £25 and the third at £35. The toys use the following materials. (A '-' means none is required.)
#
# ||||||
# |-|-|-|-|-|
# ||First toy|Second toy|Third toy|Quantity available|
# |Wood|0.8m|1.0m|1.5m|150m|
# |Blue paint|30ml|10ml|60ml|4 litres|
# |Red paint|-|60ml|30ml|2 litres|
# |Green paint|50ml|30ml|40ml|5 litres|
#
# The manufacturer wants to know what numbers of toys to make to get the greatest revenue.
#
# Formulate this as a linear programming problem and solve it in Python.
