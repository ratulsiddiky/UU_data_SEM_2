# %% [markdown]
# # Graphs - Lab Exercises

# %% [markdown]
# 1. Complete the exercises (6.1 - 6.4) in the main Graphs notebook if you have not done so already.

# %% [markdown]
# 2. Copy the code used to create and display the first graph in section 6.1, but now use a different layout to display it. Instead of specifying the position of each vertex, try out some of the other layouts, e.g. circular, planar, random, spring - see https://networkx.org/documentation/stable/reference/drawing.html

# %% [markdown]
# 3. In the cell below add a new vertex (or node) "e" to the graph you created in question 2 using the `add_node` function (see https://networkx.org/documentation/stable/tutorial.html#nodes) and add edges between "e" and all of the other vertices. Then redisplay the graph using the circular layout. (Note: you do not need to copy all the code again, just add the extra vertex and edges before redisplaying.)

# %% [markdown]
# 4. Write code to verify the Handshaking theorem for the graph in question 3.
# (Hint: You can make use of the `nodes` and `number_of_edges` functions, see https://networkx.org/documentation/stable/reference/functions.html <br>
# You can use a loop to go through all of the nodes adding up their degrees using the function `degree`)

# %% [markdown]
# 5. Verify your answer to Exercise 6.3 by a) creating the adjacency matrix, b) converting it into an undirected graph, and c) displaying it using the planar layout.

# %% [markdown]
# 6. Verify your solution to Exercise 6.4 using Python.\
# (Hint: See the main Graphs notebook to see how to determine the shortest path. To find all the paths (or simple paths) see https://networkx.org/documentation/stable/reference/algorithms/simple_paths.html)

# %% [markdown]
# 7. Create the Karate Club Network, see https://networkx.org/documentation/stable/reference/generated/networkx.generators.social.karate_club_graph.html and display it using the spring_layout.\
# a) Check whether the graph is connected\
# b) Find the vertex with the highest degree\
# c) Find the adjacency matrix for this graph and display the first row (i.e. for vertex 0). You should use the function `to_numpy_array`, see https://networkx.org/documentation/stable/reference/generated/networkx.convert_matrix.to_numpy_array.html \
# d) Find the shortest path between vertices 10 and 20.\
# e) Find and display the subgraph of the Karate Club Network consisting of the vertices 0, 5, 10, 20, 23, 32, 33 and determine whether it is connected.
