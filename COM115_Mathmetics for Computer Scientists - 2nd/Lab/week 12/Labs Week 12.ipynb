# %% [markdown]
# # Labs Week 12

# %% [markdown]
# ## Exercise 1:
#
# Three friends, Alice, Bob, and Charlie, are playing a dice game. Each friend has a different set of dice:
# - Alice has 4 four-sided dice (4d4)
# - Bob has 6 six-sided dice (6d6)
# - Charlie has 3 ten-sided dice (3d10)
#
# They decide to throw all their dice simultaneously and sum up the results. They want to know the probability of getting a total sum of more than 50.

# %% [markdown]
# ## Exercise 2:
#
# Imagine you're sitting at a poker table, eagerly awaiting your hand. In the game of poker, luck plays a significant role, but so does strategy and skill. As the dealer shuffles the deck of 52 cards and prepares to deal, you can't help but wonder: what are the odds of receiving a winning hand?
#
# In poker, a "poker hand" refers to a set of five cards dealt to a player. The strength of your hand determines your chances of winning the game. The hierarchy of poker hands ranges from the highest-ranking hands, such as a royal flush or straight flush, to lower-ranking hands like one pair or high card.
#
# As the cards are dealt, you eagerly await the outcome, hoping for a favorable hand that will give you an edge over your opponents. But with so many possible combinations of cards, calculating the probability of receiving a specific poker hand can be quite challenging.
#
# You want to know the likelihood of being dealt poker (four cards with the same number) hand when you receive 5 cards from the deck. This could be a high-ranking hand like a full house or a more common hand like two pair or three of a kind.
#
# Can you useMontecarlo to compute this probability?
